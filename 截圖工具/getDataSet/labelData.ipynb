# %%
import os
import cv2

categories = [j+i for i in 'cdhs' for j in "23456789TJQKA"]
data_path = "./data"

index = 0
for img_name in os.listdir(data_path):
    print(img_name)
    if not os.path.exists(os.path.join('label/', categories[index])):
        os.makedirs(os.path.join('label/', categories[index]))
    
    img = cv2.imread(os.path.join(data_path, img_name), cv2.IMREAD_COLOR)
    
    # 将图像转换为灰度图
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # 对灰度图应用 Sobel 边缘检测
    sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=1)
    sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=1)
    
    # 将 Sobel X 和 Sobel Y 合并为边缘强度图像
    edges = cv2.magnitude(sobelx, sobely)
    edges = cv2.convertScaleAbs(edges)
    

    cropped_edges = edges[:52, :28]


    # 保存处理后的图像
    cv2.imwrite(os.path.join('label/', categories[index], img_name), cropped_edges)

    index += 1
    index %= 52
# Out:
# card0010.png
# card0011.png
# card0012.png
# card0013.png
# card0014.png
# card0015.png
# card0016.png
# card0017.png
# card0018.png
# card0019.png
# card0020.png
# card0021.png
# card0022.png
# card0023.png
# card0024.png
# card0025.png
# card0026.png
# card0027.png
# card0028.png
# card0029.png
# card0030.png
# card0031.png
# card0032.png
# card0033.png
# card0034.png
# card0035.png
# card0036.png
# card0037.png
# card0038.png
# card0039.png
# card0040.png
# card0041.png
# card0042.png
# card0043.png
# card0044.png
# card0045.png
# card0046.png
# card0047.png
# card0048.png
# card0049.png
# card0050.png
# card0051.png
# card0052.png
# card0053.png
# card0054.png
# card0055.png
# card0056.png
# card0057.png
# card0058.png
# card0059.png
# card0060.png
# card0061.png
# card0070.png
# card0071.png
# card0072.png
# card0073.png
# card0074.png
# card0075.png
# card0076.png
# card0077.png
# card0078.png
# card0079.png
# card0080.png
# card0081.png
# card0082.png
# card0083.png
# ...

# %%
categories = [j+i for i in 'cdhs' for j in "23456789TJQKA"]
